# %%
import h5py
f = h5py.File('/home/zhli7/deepst/TaxiBJ/HF_M32xM32_H1_InOut.h5', 'r')
f.keys()
# Out:
# [u'data', u'date']

# %%
import numpy as np
to_string = lambda x: str(x)
to_string_vectorized = np.vectorize(to_string)
to_string_vectorized(f['date'].value)
# Out:
# array(['2017020100', '2017020101', '2017020102', '2017020103',
#        '2017020104', '2017020105', '2017020106', '2017020107',
#        '2017020108', '2017020109', '2017020110', '2017020111',
#        '2017020112', '2017020113', '2017020114', '2017020115',
#        '2017020116', '2017020117', '2017020118', '2017020119',
#        '2017020120', '2017020121', '2017020122', '2017020123',
#        '2017020200', '2017020201', '2017020202', '2017020203',
#        '2017020204', '2017020205', '2017020206', '2017020207',
#        '2017020208', '2017020209', '2017020210', '2017020211',
#        '2017020212', '2017020213', '2017020214', '2017020215',
#        '2017020216', '2017020217', '2017020218', '2017020219',
#        '2017020220', '2017020221', '2017020222', '2017020223',
#        '2017020300', '2017020301', '2017020302', '2017020303',
#        '2017020304', '2017020305', '2017020306', '2017020307',
#        '2017020308', '2017020309', '2017020310', '2017020311',
# ...

# %%
f['data'].shape
# Out:
# (672, 2, 32, 32)

# %%
import numpy as np
# Out:
# array([[  1,   4, 142, ...,   0,   0,   0],
#        [  1,   4,   3, ...,   0,   0,   0],
#        [  1,   4,  60, ...,   0,   0,   0],
#        ...,
#        [  1,   4, 249, ...,   0,   0,   0],
#        [  1,  16, 186, ...,   0,   0,   0],
#        [  1,   4, 571, ...,   0,   0,   0]], dtype=int32)

# %%
from __future__ import division

# %%
4//3
# Out:
# 1

# %%
taxi = h5py.File('/home/zhli7/deepst/TaxiBJ/BJ13_M32x32_T30_InOut.h5', 'r')

# %%
taxi['date'].value
# Out:
# array(['2013070101', '2013070102', '2013070103', ..., '2013102946',
#        '2013102947', '2013102948'],
#       dtype='|S10')
