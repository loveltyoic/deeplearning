# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# Out:
# Data size 17005207

# %%
def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 12 as
# 3084 originated -> 5239 anarchism
# 12 as -> 3084 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  255.18989563
# Nearest to which: theatrically, bootlegged, vivo, instance, campaigner, brushes, lolita, avar,
# Nearest to first: indexing, elaborates, expediency, affonso, hypertext, guantanamo, veer, daylight,
# Nearest to UNK: free, superhero, facing, mitotic, euler, wrap, dandyism, harker,
# Nearest to his: myra, teas, encoding, intuition, nabonidus, owl, kimi, harmala,
# Nearest to would: vietnamese, royal, mongolia, portability, destabilization, alamos, readily, rind,
# Nearest to have: epa, penitence, fermentation, abusing, benchmarking, broaden, harcourt, because,
# Nearest to zero: phonemic, inflexible, mohr, thespis, elias, kochi, invasions, trailing,
# Nearest to time: mez, software, childish, bare, overpopulation, aristocratic, berger, teenagers,
# Nearest to called: mistaken, admiration, extends, animalium, vicar, stratigraphy, guessing, dyck,
# Nearest to about: emcee, rupert, oprah, bsa, fluctuate, oddly, fillmore, bitters,
# Nearest to may: projections, materialist, inducing, carbonate, backbench, fairchild, lingering, referential,
# Nearest to on: clowns, singleton, percussion, filmmakers, magic, buddy, ernesto, constitutional,
# Nearest to most: jamil, installation, bottle, enters, explaining, mandy, petersen, anatomy,
# Nearest to no: bartender, covens, monads, malawian, chihuahua, zeta, giles, yoshitaka,
# Nearest to during: builds, disassembled, hdz, ceremonies, insertion, minsk, nonverbal, orgy,
# Nearest to and: rounder, rehearsing, pressed, transfinite, machado, eikon, cross, heathen,
# Average loss at step  2000 :  113.754118066
# Average loss at step  4000 :  53.3510710182
# Average loss at step  6000 :  32.9766881282
# Average loss at step  8000 :  23.4552368197
# Average loss at step  10000 :  17.6660819814
# Nearest to which: one, theatrically, instance, partner, UNK, revolution, bernhard, this,
# Nearest to first: neighbors, mein, far, verse, agave, figure, youth, library,
# Nearest to UNK: canaris, bckgr, and, phi, one, var, agave, the,
# Nearest to his: the, owl, rudolph, encoding, aardvark, evidence, s, a,
# Nearest to would: vietnamese, invaders, archie, computing, phi, alamos, to, readily,
# Nearest to have: has, be, effort, had, pago, mal, because, present,
# Nearest to zero: nine, eight, phi, bckgr, agave, six, three, seven,
# Nearest to time: software, archie, pages, solstice, gb, advocates, bare, reals,
# Nearest to called: extends, animalium, admiration, nucleus, mistaken, movements, catches, francs,
# Nearest to about: tour, acts, nine, promise, comte, indy, covert, oddly,
# Nearest to may: projections, algal, references, pseudo, founded, zero, processing, nine,
# Nearest to on: in, and, of, phi, percussion, once, constitutional, to,
# Nearest to most: bottle, enters, agave, anatomy, installation, product, explaining, whom,
# Nearest to no: nine, j, screening, chihuahua, saints, vs, nfl, bartender,
# Nearest to during: pages, agave, vs, ceremonies, lectionis, infant, winning, views,
# Nearest to and: in, of, UNK, the, for, by, on, agave,
# Average loss at step  12000 :  14.186735364
# Average loss at step  14000 :  11.7417899318
# Average loss at step  16000 :  9.97917088449
# Average loss at step  18000 :  8.36432086098
# Average loss at step  20000 :  7.93813412571
# Nearest to which: this, and, that, partner, theatrically, it, dasyprocta, also,
# Nearest to first: mein, livonia, neighbors, saving, verse, youth, lizard, agouti,
# Nearest to UNK: agouti, dasyprocta, circ, aoc, phi, canaris, and, operatorname,
# Nearest to his: the, s, agouti, this, a, owl, its, evidence,
# Nearest to would: invaders, to, vietnamese, archie, computing, phi, alabaster, readily,
# Nearest to have: be, had, has, mal, pago, widow, onyx, effort,
# Nearest to zero: nine, eight, five, six, seven, circ, phi, agouti,
# Nearest to time: agouti, software, operatorname, archie, clean, overpopulation, solstice, asa,
# Nearest to called: extends, animalium, mistaken, admiration, nucleus, contingency, fluid, waged,
# Nearest to about: nine, five, promise, six, indy, comte, rupert, kumar,
# Nearest to may: can, projections, pseudo, censor, to, algal, ja, inducing,
# Nearest to on: in, and, at, agouti, phi, two, of, for,
# Nearest to most: enters, bottle, explaining, installation, agave, many, condorcet, anatomy,
# Nearest to no: screening, operatorname, not, might, saints, roller, kingdoms, atkins,
# Nearest to during: of, apologia, ceremonies, by, schwarzenegger, pages, agouti, infant,
# Nearest to and: or, agouti, in, of, dasyprocta, for, the, circ,
# Average loss at step  22000 :  7.02005361712
# Average loss at step  24000 :  6.75906175518
# Average loss at step  26000 :  6.7176571368
# Average loss at step  28000 :  6.32247729635
# Average loss at step  30000 :  5.94851525474
# Nearest to which: that, this, it, also, trinomial, and, partner, dasyprocta,
# Nearest to first: trinomial, livonia, saving, mein, violation, neighbors, agouti, youth,
# Nearest to UNK: agouti, dasyprocta, circ, trinomial, canaris, phi, six, two,
# Nearest to his: the, their, its, her, s, owl, this, agouti,
# Nearest to would: invaders, to, could, may, vietnamese, phi, computing, archie,
# Nearest to have: be, had, has, mal, were, are, pago, onyx,
# Nearest to zero: eight, five, six, nine, seven, four, agouti, phi,
# Nearest to time: software, agouti, operatorname, clean, solstice, archie, asa, bare,
# Nearest to called: extends, mistaken, admiration, animalium, bpp, healthcare, waged, francs,
# Nearest to about: promise, six, five, indy, nine, acts, jubilees, kumar,
# Nearest to may: can, would, projections, could, to, nine, censor, pseudo,
# Nearest to on: in, at, from, two, agouti, and, phi, circ,
# Nearest to most: enters, bottle, many, explaining, installation, agave, auschwitz, anatomy,
# Nearest to no: screening, there, operatorname, not, might, vocalist, roller, saints,
# Nearest to during: of, by, in, apologia, ceremonies, schwarzenegger, pages, infant,
# Nearest to and: or, agouti, in, dasyprocta, amalthea, circ, agave, of,
# Average loss at step  32000 :  5.88166729605
# Average loss at step  34000 :  5.70543767834
# Average loss at step  36000 :  5.77856686223
# Average loss at step  38000 :  5.52363845766
# Average loss at step  40000 :  5.24955285072
# Nearest to which: that, this, it, also, one, trinomial, agouti, dasyprocta,
# Nearest to first: trinomial, livonia, neighbors, recitative, saving, anticipating, nacional, violation,
# Nearest to UNK: agouti, dasyprocta, circ, four, canaris, three, arin, zero,
# Nearest to his: the, their, its, her, owl, agouti, s, this,
# Nearest to would: invaders, could, to, may, will, they, can, phi,
# Nearest to have: had, has, be, were, are, pago, mal, onyx,
# Nearest to zero: eight, seven, five, six, four, nine, agouti, dasyprocta,
# Nearest to time: agouti, software, clean, operatorname, archie, solstice, overpopulation, bare,
# Nearest to called: extends, mistaken, healthcare, ratites, bpp, laminal, admiration, levant,
# Nearest to about: promise, five, indy, rupert, harlem, deciding, kumar, six,
# Nearest to may: can, would, twh, could, will, projections, to, must,
# Nearest to on: in, at, from, recitative, arno, agouti, phi, two,
# Nearest to most: many, enters, explaining, installation, bottle, guderian, agave, auschwitz,
# Nearest to no: there, screening, operatorname, roller, a, might, vocalist, accumulate,
# Nearest to during: in, by, of, schwarzenegger, apologia, ceremonies, agouti, through,
# Nearest to and: or, in, amalthea, agouti, zero, but, recitative, circ,
# Average loss at step  42000 :  5.39893575215
# Average loss at step  44000 :  5.25764010894
# Average loss at step  46000 :  5.19729067051
# Average loss at step  48000 :  5.23677841115
# Average loss at step  50000 :  4.9871265986
# Nearest to which: this, that, also, it, one, kapoor, and, who,
# Nearest to first: trinomial, neighbors, recitative, anticipating, saving, reims, nacional, following,
# Nearest to UNK: agouti, dasyprocta, circ, canaris, operatorname, bckgr, four, trinomial,
# Nearest to his: their, the, its, her, s, owl, this, agouti,
# Nearest to would: could, invaders, to, may, can, will, erich, eight,
# Nearest to have: had, be, has, were, are, mal, pago, onyx,
# Nearest to zero: eight, seven, five, six, four, nine, three, dasyprocta,
# Nearest to time: agouti, software, clean, archie, solstice, operatorname, arrival, overpopulation,
# Nearest to called: and, extends, healthcare, mistaken, ratites, bpp, laminal, guessing,
# Nearest to about: promise, five, indy, harlem, six, deciding, rupert, kumar,
# Nearest to may: can, would, will, could, twh, must, projections, to,
# Nearest to on: in, at, two, recitative, agouti, phi, from, dasyprocta,
# Nearest to most: many, explaining, enters, installation, agave, guderian, bottle, some,
# Nearest to no: there, a, roller, might, screening, saints, vocalist, operatorname,
# Nearest to during: in, by, of, schwarzenegger, six, four, through, apologia,
# Nearest to and: or, but, eight, six, agouti, four, circ, agave,
# Average loss at step  52000 :  5.04695144749
# Average loss at step  54000 :  5.17637325132
# Average loss at step  56000 :  5.04424764335
# Average loss at step  58000 :  5.07671826947
# Average loss at step  60000 :  4.96368403304
# Nearest to which: this, that, also, it, who, kapoor, but, agouti,
# Nearest to first: trinomial, recitative, reims, saving, neighbors, second, agouti, following,
# Nearest to UNK: agouti, dasyprocta, circ, ursus, michelob, operatorname, pulau, apatosaurus,
# Nearest to his: their, her, its, the, s, agouti, gigantopithecus, this,
# Nearest to would: could, may, can, invaders, will, to, erich, they,
# Nearest to have: had, has, be, were, are, pago, trip, onyx,
# Nearest to zero: eight, seven, six, five, nine, four, ursus, three,
# Nearest to time: agouti, software, clean, solstice, archie, operatorname, batted, arrival,
# Nearest to called: extends, healthcare, guessing, bpp, mistaken, ratites, dyck, laminal,
# Nearest to about: harlem, indy, promise, five, deciding, rupert, six, covert,
# Nearest to may: can, would, could, will, must, twh, projections, should,
# Nearest to on: in, at, from, recitative, agouti, over, upon, phi,
# Nearest to most: many, explaining, enters, some, ursus, installation, agave, sanjaks,
# Nearest to no: a, there, any, roller, operatorname, ripe, vocalist, screening,
# Nearest to during: in, by, four, through, of, when, six, agouti,
# Nearest to and: or, but, agouti, recitative, ursus, four, kapoor, in,
# Average loss at step  62000 :  5.0358351233
# Average loss at step  64000 :  4.84624108362
# Average loss at step  66000 :  4.58081713545
# Average loss at step  68000 :  4.98648167908
# Average loss at step  70000 :  4.89627061486
# Nearest to which: that, this, also, it, who, one, cebus, but,
# Nearest to first: trinomial, second, government, reims, recitative, neighbors, amendments, following,
# Nearest to UNK: agouti, dasyprocta, cebus, ursus, michelob, seven, circ, apatosaurus,
# Nearest to his: their, her, its, the, s, agouti, gigantopithecus, encoding,
# Nearest to would: could, can, may, will, invaders, to, must, they,
# Nearest to have: had, has, were, be, are, onyx, pago, yoannis,
# Nearest to zero: eight, five, six, seven, four, nine, three, ursus,
# Nearest to time: agouti, software, clean, solstice, cebus, archie, thibetanus, overpopulation,
# Nearest to called: extends, and, bpp, ratites, guessing, dyck, healthcare, laminal,
# Nearest to about: mascarenhas, indy, harlem, promise, deciding, clo, that, rupert,
# Nearest to may: can, would, will, could, must, twh, should, might,
# Nearest to on: in, at, recitative, from, upon, agouti, circ, over,
# Nearest to most: many, explaining, some, mitral, more, enters, ursus, upanija,
# Nearest to no: any, there, roller, vocalist, ripe, a, might, hadad,
# Nearest to during: in, by, when, through, agouti, before, however, ursus,
# Nearest to and: or, but, kapoor, agouti, recitative, ursus, dasyprocta, cebus,
# Average loss at step  72000 :  4.75380150533
# Average loss at step  74000 :  4.82087748373
# Average loss at step  76000 :  4.73435999846
# Average loss at step  78000 :  4.80401059675
# Average loss at step  80000 :  4.79168749475
# Nearest to which: that, this, also, it, who, cebus, but, one,
# Nearest to first: second, trinomial, reims, vec, following, anticipating, last, neighbors,
# Nearest to UNK: agouti, dasyprocta, ursus, circ, cebus, michelob, iit, operatorname,
# Nearest to his: their, her, its, the, s, mede, encoding, fringed,
# Nearest to would: could, may, can, will, invaders, to, must, might,
# Nearest to have: had, has, were, be, are, onyx, follow, pago,
# Nearest to zero: five, four, eight, six, seven, nine, ursus, operatorname,
# Nearest to time: agouti, software, clean, solstice, cebus, archie, thibetanus, atacama,
# Nearest to called: ratites, extends, bpp, laminal, healthcare, localized, guessing, dyck,
# Nearest to about: mascarenhas, harlem, indy, deciding, that, clo, promise, rupert,
# Nearest to may: can, would, will, could, must, twh, should, might,
# Nearest to on: in, at, recitative, agouti, upon, circ, from, microcebus,
# Nearest to most: many, some, more, explaining, mitral, ursus, sanjaks, sharon,
# Nearest to no: any, there, ripe, roller, vocalist, might, a, operatorname,
# Nearest to during: in, by, through, when, of, however, after, agouti,
# Nearest to and: or, but, agouti, dasyprocta, thaler, kapoor, circ, recitative,
# Average loss at step  82000 :  4.77061797416
# Average loss at step  84000 :  4.73698490667
# Average loss at step  86000 :  4.77563549578
# Average loss at step  88000 :  4.73865837789
# Average loss at step  90000 :  4.72921168458
# Nearest to which: that, this, but, it, also, who, and, cebus,
# Nearest to first: second, last, reims, anticipating, following, vec, trinomial, recitative,
# Nearest to UNK: agouti, dasyprocta, ursus, cebus, michelob, operatorname, circ, callithrix,
# Nearest to his: their, her, its, the, s, gigantopithecus, fringed, mede,
# Nearest to would: could, may, can, will, invaders, to, might, must,
# Nearest to have: had, has, were, are, be, having, onyx, follow,
# Nearest to zero: five, eight, seven, six, nine, four, ursus, operatorname,
# Nearest to time: agouti, software, clean, year, solstice, overpopulation, thibetanus, archie,
# Nearest to called: ratites, extends, bpp, UNK, healthcare, callithrix, laminal, and,
# Nearest to about: mascarenhas, harlem, indy, clo, over, deciding, but, abet,
# Nearest to may: can, would, will, could, must, might, should, twh,
# Nearest to on: in, recitative, at, upon, agouti, from, circ, microcebus,
# Nearest to most: many, some, more, explaining, mitral, ursus, rupees, sanjaks,
# Nearest to no: any, there, a, calypso, ripe, roller, might, operatorname,
# Nearest to during: in, by, when, through, after, however, before, agouti,
# Nearest to and: or, but, while, agouti, recitative, six, amalthea, kapoor,
# Average loss at step  92000 :  4.67760911095
# Average loss at step  94000 :  4.72886758292
# Average loss at step  96000 :  4.69711705458
# Average loss at step  98000 :  4.5928080411
# Average loss at step  100000 :  4.70764573061
# Nearest to which: that, this, also, but, it, cebus, and, kapoor,
# Nearest to first: second, last, following, final, anticipating, reims, trinomial, same,
# Nearest to UNK: agouti, dasyprocta, ursus, circ, cebus, microsite, michelob, bckgr,
# Nearest to his: their, her, its, the, s, gigantopithecus, fringed, agouti,
# Nearest to would: could, can, may, will, must, invaders, might, should,
# Nearest to have: had, has, were, be, are, onyx, follow, having,
# Nearest to zero: eight, five, four, nine, seven, six, three, ursus,
# Nearest to time: agouti, clean, software, year, solstice, mesoplodon, thibetanus, overpopulation,
# Nearest to called: and, revolutions, bpp, northerly, extends, koruna, used, callithrix,
# Nearest to about: mascarenhas, harlem, over, indy, that, deciding, clo, on,
# Nearest to may: can, would, will, could, must, should, might, twh,
# Nearest to on: in, recitative, upon, at, from, agouti, kashmir, through,
# Nearest to most: many, some, more, explaining, mitral, ursus, especially, sanjaks,
# Nearest to no: any, a, calypso, there, ripe, might, roller, operatorname,
# Nearest to during: in, after, through, when, before, by, however, agouti,
# Nearest to and: or, but, kapoor, agouti, dasyprocta, circ, six, inequality,

# %%
# Step 6: Visualize the embeddings.
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

#   plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
